# %%
import pandas as pd
import numpy as np

data = {
    'patient_id': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110,
                   111, 112, 113, 114, 115, 101, 107, 118, 119, 120],
    'age': ['25', '34', None, '45', '29', None, '38', '52', '27', '41',
            '33', 'unknown', '48', '26', '35', '25', '38', '31', None, '44'],
    'weight': ['70', '65', '80', None, '75', None, '68', '90', '72', '85',
               '78', None, '82', '69', 'N/A', '70', '68', '74', None, '88'],
    'blood_pressure': [120, 130, None, 140, 125, None, 135, None, 118, 145,
                      128, None, 138, 122, None, 120, 135, 126, None, 142],
    'medication': ['Aspirin', 'Metformin', 'Lisinopril', None, 'Aspirin',
                   'Metformin', 'Lisinopril', 'Aspirin', None, 'Metformin',
                   'Lisinopril', 'Aspirin', None, 'Metformin', 'Aspirin',
                   'Aspirin', 'Lisinopril', 'Metformin', 'Aspirin', None],
    'insurance_provider': ['Blue Cross', 'Aetna', 'Cigna', 'UnitedHealth', None,
                          'Blue Cross', 'Aetna', 'Cigna', 'UnitedHealth', 'Blue Cross',
                          'Aetna', None, 'UnitedHealth', 'Blue Cross', 'Aetna',
                          'Blue Cross', 'Aetna', 'Cigna', 'UnitedHealth', None]
}

df = pd.DataFrame(data)

# %%
print("### Task 1: Data Inspection")
df.info()
print("\nMissing values per column:\n", df.isnull().sum())
print("\nPercentage of missing values:\n", (df.isnull().sum() / len(df)) * 100)
print("\nTotal duplicate rows:", df.duplicated().sum())
# Out:
# ### Task 1: Data Inspection
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   patient_id          20 non-null     int64
#  1   age                 17 non-null     object
#  2   weight              16 non-null     object
#  3   blood_pressure      14 non-null     float64
#  4   medication          16 non-null     object
#  5   insurance_provider  17 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.1+ KB
#
# Missing values per column:
#  patient_id            0
# age                   3
# weight                4
# blood_pressure        6
# medication            4
# insurance_provider    3
# dtype: int64
#
# Percentage of missing values:
#  patient_id             0.0
# age                   15.0
# weight                20.0
# blood_pressure        30.0
# medication            20.0
# insurance_provider    15.0
# dtype: float64
#
# Total duplicate rows: 2

# %%
print("\n### Task 2: Data Type Conversion")

df['age'] = pd.to_numeric(df['age'], errors='coerce')
df['weight'] = pd.to_numeric(df['weight'], errors='coerce')
# Out:
# ### Task 2: Data Type Conversion

# %%
print(f"Missing ages after conversion: {df['age'].isnull().sum()}")
print(f"Missing weights after conversion: {df['weight'].isnull().sum()}")
# Out:
# Missing ages after conversion: 4
# Missing weights after conversion: 5

# %%
df['insurance_provider'] = df['insurance_provider'].astype('category')
print("\nVerified Data Types:\n", df.dtypes)
# Out:
# Verified Data Types:
#  patient_id               int64
# age                    float64
# weight                 float64
# blood_pressure         float64
# medication              object
# insurance_provider    category
# dtype: object

# %%
print("\n### Task 3: Handling Missing Values")
df['age'] = df['age'].fillna(df['age'].median())
df['weight'] = df['weight'].fillna(df['weight'].median())
df['blood_pressure'] = df['blood_pressure'].fillna(df['blood_pressure'].median())
# Out:
# ### Task 3: Handling Missing Values

# %%
df['medication'] = df['medication'].fillna(df['medication'].mode()[0])

# %%
df['insurance_provider'] = df['insurance_provider'].fillna('Unknown')

print("Remaining missing values:", df.isnull().sum().sum())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_311/3951889788.py in <cell line: 0>()
# ----> 1 df['insurance_provider'] = df['insurance_provider'].fillna('Unknown')
#       2
#       3 print("Remaining missing values:", df.isnull().sum().sum())
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    7347                     )
#    7348
# -> 7349                 new_data = self._mgr.fillna(
#    7350                     value=value, limit=limit, inplace=inplace, downcast=downcast
#    7351                 )
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/base.py in fillna(self, value, limit, inplace, downcast)
#     184             limit = libalgos.validate_limit(None, limit=limit)
#     185
# --> 186         return self.apply_with_block(
#     187             "fillna",
#     188             value=value,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     361                 applied = b.apply(f, **kwargs)
#     362             else:
# --> 363                 applied = getattr(b, f)(**kwargs)
#     364             result_blocks = extend_blocks(applied, result_blocks)
#     365
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/blocks.py in fillna(self, value, limit, inplace, downcast, using_cow, already_warned)
#    2332                 # 3rd party EA that has not implemented copy keyword yet
#    2333                 refs = None
# -> 2334                 new_values = self.values.fillna(value=value, method=None, limit=limit)
#    2335                 # issue the warning *after* retrying, in case the TypeError
#    2336                 #  was caused by an invalid fill_value
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arrays/_mixins.py in fillna(self, value, method, limit, copy)
#     370                 else:
#     371                     new_values = self[:]
# --> 372                 new_values[mask] = value
#     373         else:
#     374             # We validate the fill_value even if there is nothing to fill
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arrays/_mixins.py in __setitem__(self, key, value)
#     259     def __setitem__(self, key, value) -> None:
#     260         key = check_array_indexer(self, key)
# --> 261         value = self._validate_setitem_value(value)
#     262         self._ndarray[key] = value
#     263
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arrays/categorical.py in _validate_setitem_value(self, value)
#    1587             return self._validate_listlike(value)
#    1588         else:
# -> 1589             return self._validate_scalar(value)
#    1590
#    1591     def _validate_scalar(self, fill_value):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arrays/categorical.py in _validate_scalar(self, fill_value)
#    1612             fill_value = self._unbox_scalar(fill_value)
#    1613         else:
# -> 1614             raise TypeError(
#    1615                 "Cannot setitem on a Categorical with a new "
#    1616                 f"category ({fill_value}), set the categories first"
#
# TypeError: Cannot setitem on a Categorical with a new category (Unknown), set the categories first

# %%
df['insurance_provider'] = df['insurance_provider'].cat.add_categories('Unknown')
df['insurance_provider'] = df['insurance_provider'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# patient_id            0
# age                   0
# weight                0
# blood_pressure        0
# medication            0
# insurance_provider    0
# dtype: int64

# %%
print("\n### Task 4: Handling Duplicates")
print("Duplicate patient IDs identified:\n", df[df.duplicated(subset=['patient_id'], keep=False)])

shape_before = df.shape
df = df.drop_duplicates(subset=['patient_id'], keep='first')
shape_after = df.shape

print(f"Rows removed: {shape_before[0] - shape_after[0]}")
# Out:
# ### Task 4: Handling Duplicates
# Duplicate patient IDs identified:
#      patient_id   age  weight  blood_pressure  medication insurance_provider
# 0          101  25.0    70.0           120.0     Aspirin         Blue Cross
# 6          107  38.0    68.0           135.0  Lisinopril              Aetna
# 15         101  25.0    70.0           120.0     Aspirin         Blue Cross
# 16         107  38.0    68.0           135.0  Lisinopril              Aetna
# Rows removed: 2

# %%
import pandas as pd
import numpy as np

data = {
    'patient_id': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110,
                   111, 112, 113, 114, 115, 101, 107, 118, 119, 120],
    'age': ['25', '34', None, '45', '29', None, '38', '52', '27', '41',
            '33', 'unknown', '48', '26', '35', '25', '38', '31', None, '44'],
    'weight': ['70', '65', '80', None, '75', None, '68', '90', '72', '85',
               '78', None, '82', '69', 'N/A', '70', '68', '74', None, '88'],
    'blood_pressure': [120, 130, None, 140, 125, None, 135, None, 118, 145,
                       128, None, 138, 122, None, 120, 135, 126, None, 142],
    'medication': ['Aspirin', 'Metformin', 'Lisinopril', None, 'Aspirin',
                   'Metformin', 'Lisinopril', 'Aspirin', None, 'Metformin',
                   'Lisinopril', 'Aspirin', None, 'Metformin', 'Aspirin',
                   'Aspirin', 'Lisinopril', 'Metformin', 'Aspirin', None],
    'insurance_provider': ['Blue Cross', 'Aetna', 'Cigna', 'UnitedHealth', None,
                          'Blue Cross', 'Aetna', 'Cigna', 'UnitedHealth', 'Blue Cross',
                          'Aetna', None, 'UnitedHealth', 'Blue Cross', 'Aetna',
                          'Blue Cross', 'Aetna', 'Cigna', 'UnitedHealth', None]
}

df = pd.DataFrame(data)

# %%
df_clean = df.copy()

# %%
print("======= VERIFICATION REPORT: BEFORE =======")
print(f"Shape: {df_clean.shape}")
print(f"Total Missing Values: {df_clean.isnull().sum().sum()}")
print(f"Total Duplicates (patient_id): {df_clean.duplicated(subset=['patient_id']).sum()}")
print(f"Data Types:\n{df_clean.dtypes}\n")
# Out:
# ======= VERIFICATION REPORT: BEFORE =======
# Shape: (20, 6)
# Total Missing Values: 20
# Total Duplicates (patient_id): 2
# Data Types:
# patient_id              int64
# age                    object
# weight                 object
# blood_pressure        float64
# medication             object
# insurance_provider     object
# dtype: object

# %%
df_clean['age'] = pd.to_numeric(df_clean['age'], errors='coerce')
df_clean['weight'] = pd.to_numeric(df_clean['weight'], errors='coerce')

df_clean['insurance_provider'] = df_clean['insurance_provider'].astype('category')

# %%
df_clean['age'] = df_clean['age'].fillna(df_clean['age'].median())
df_clean['weight'] = df_clean['weight'].fillna(df_clean['weight'].median())
df_clean['blood_pressure'] = df_clean['blood_pressure'].fillna(df_clean['blood_pressure'].median())
df_clean['medication'] = df_clean['medication'].fillna(df_clean['medication'].mode()[0])
df_clean['insurance_provider'] = df_clean['insurance_provider'].fillna('Unknown')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_311/1794902764.py in <cell line: 0>()
#       3 df_clean['blood_pressure'] = df_clean['blood_pressure'].fillna(df_clean['blood_pressure'].median())
#       4 df_clean['medication'] = df_clean['medication'].fillna(df_clean['medication'].mode()[0])
# ----> 5 df_clean['insurance_provider'] = df_clean['insurance_provider'].fillna('Unknown')
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    7347                     )
#    7348
# -> 7349                 new_data = self._mgr.fillna(
#    7350                     value=value, limit=limit, inplace=inplace, downcast=downcast
#    7351                 )
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/base.py in fillna(self, value, limit, inplace, downcast)
#     184             limit = libalgos.validate_limit(None, limit=limit)
#     185
# --> 186         return self.apply_with_block(
#     187             "fillna",
#     188             value=value,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     361                 applied = b.apply(f, **kwargs)
#     362             else:
# --> 363                 applied = getattr(b, f)(**kwargs)
#     364             result_blocks = extend_blocks(applied, result_blocks)
#     365
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/blocks.py in fillna(self, value, limit, inplace, downcast, using_cow, already_warned)
#    2332                 # 3rd party EA that has not implemented copy keyword yet
#    2333                 refs = None
# -> 2334                 new_values = self.values.fillna(value=value, method=None, limit=limit)
#    2335                 # issue the warning *after* retrying, in case the TypeError
#    2336                 #  was caused by an invalid fill_value
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arrays/_mixins.py in fillna(self, value, method, limit, copy)
#     370                 else:
#     371                     new_values = self[:]
# --> 372                 new_values[mask] = value
#     373         else:
#     374             # We validate the fill_value even if there is nothing to fill
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arrays/_mixins.py in __setitem__(self, key, value)
#     259     def __setitem__(self, key, value) -> None:
#     260         key = check_array_indexer(self, key)
# --> 261         value = self._validate_setitem_value(value)
#     262         self._ndarray[key] = value
#     263
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arrays/categorical.py in _validate_setitem_value(self, value)
#    1587             return self._validate_listlike(value)
#    1588         else:
# -> 1589             return self._validate_scalar(value)
#    1590
#    1591     def _validate_scalar(self, fill_value):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arrays/categorical.py in _validate_scalar(self, fill_value)
#    1612             fill_value = self._unbox_scalar(fill_value)
#    1613         else:
# -> 1614             raise TypeError(
#    1615                 "Cannot setitem on a Categorical with a new "
#    1616                 f"category ({fill_value}), set the categories first"
#
# TypeError: Cannot setitem on a Categorical with a new category (Unknown), set the categories first

# %%
df_clean['age'] = df_clean['age'].fillna(df_clean['age'].median())
df_clean['weight'] = df_clean['weight'].fillna(df_clean['weight'].median())
df_clean['blood_pressure'] = df_clean['blood_pressure'].fillna(df_clean['blood_pressure'].median())

df_clean['medication'] = df_clean['medication'].fillna(df_clean['medication'].mode()[0])

# Fix categorical fill issue
df_clean['insurance_provider'] = df_clean['insurance_provider'].cat.add_categories('Unknown')
df_clean['insurance_provider'] = df_clean['insurance_provider'].fillna('Unknown')

# %%
df_clean = df_clean.drop_duplicates(subset=['patient_id'], keep='first')

# %%
print("======= VERIFICATION REPORT: BEFORE =======")
print(f"Shape: {df_clean.shape}")
print(f"Missing values total: {df_clean.isnull().sum().sum()}")
print(f"Duplicate patient IDs: {df_clean.duplicated(subset=['patient_id']).sum()}")
print(f"Data types:\n{df_clean.dtypes}")
print("-" * 43).. because of clean code "Before" report looks identical to the "After" report.
# Out:
# ======= VERIFICATION REPORT: BEFORE =======
# Shape: (18, 6)
# Missing values total: 0
# Duplicate patient IDs: 0
# Data types:
# patient_id               int64
# age                    float64
# weight                 float64
# blood_pressure         float64
# medication              object
# insurance_provider    category
# dtype: object
# -------------------------------------------

# %%
print("======= VERIFICATION REPORT: AFTER =======")
print(f"Shape: {df_clean.shape}")
print(f"Missing values per column:\n{df_clean.isnull().sum()}")
print(f"Total Duplicates (patient_id): {df_clean.duplicated(subset=['patient_id']).sum()}")
print(f"Data types:\n{df_clean.dtypes}")
# Out:
# ======= VERIFICATION REPORT: AFTER =======
# Shape: (18, 6)
# Missing values per column:
# patient_id            0
# age                   0
# weight                0
# blood_pressure        0
# medication            0
# insurance_provider    0
# dtype: int64
# Total Duplicates (patient_id): 0
# Data types:
# patient_id               int64
# age                    float64
# weight                 float64
# blood_pressure         float64
# medication              object
# insurance_provider    category
# dtype: object
